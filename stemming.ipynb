# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
words = ['drive', 'driving','driver', 'driver', 'drives', 'drove', 'cats', 'children']

# %%
for w in words:
  print(ps.stem(w))
# Out:
# drive
# drive
# driver
# driver
# drive
# drove
# cat
# children
