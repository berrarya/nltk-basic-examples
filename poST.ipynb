# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
text = "Friedrich Wilhelm Nietzsche was a German classical philologist and philosopher. Nietzsche's ideas and style broke established thought patterns, so he could not be included in a classical discipline that existed during his time. Nietzsche is now considered the founder of the philosophy of life discipline, a brand new philosophical school."

# %%
tokenized = nltk.word_tokenize(text)

# %%
nltk.pos_tag(tokenized)
# Out:
# [('Friedrich', 'NNP'),
#  ('Wilhelm', 'NNP'),
#  ('Nietzsche', 'NNP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('German', 'JJ'),
#  ('classical', 'JJ'),
#  ('philologist', 'NN'),
#  ('and', 'CC'),
#  ('philosopher', 'NN'),
#  ('.', '.'),
#  ('Nietzsche', 'NNP'),
#  ("'s", 'POS'),
#  ('ideas', 'NNS'),
#  ('and', 'CC'),
#  ('style', 'NN'),
#  ('broke', 'VBD'),
#  ('established', 'VBN'),
#  ('thought', 'NN'),
#  ('patterns', 'NNS'),
#  (',', ','),
#  ('so', 'IN'),
#  ('he', 'PRP'),
#  ('could', 'MD'),
#  ('not', 'RB'),
#  ('be', 'VB'),
#  ('included', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('classical', 'JJ'),
#  ('discipline', 'NN'),
#  ('that', 'WDT'),
#  ('existed', 'VBD'),
#  ('during', 'IN'),
#  ('his', 'PRP$'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('Nietzsche', 'NNP'),
#  ('is', 'VBZ'),
#  ('now', 'RB'),
#  ('considered', 'VBN'),
#  ('the', 'DT'),
#  ('founder', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('philosophy', 'NN'),
#  ('of', 'IN'),
#  ('life', 'NN'),
# ...
